# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane is AI-assisted content research and recommendation. I want to study how data and machine learning can help identify useful content opportunities and make better content decisions. I chose this lane because it can reduce manual research, improve content planning, and support data-driven recommendations.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The question is: How can data-driven recommendations help decide which content opportunities should be prioritized? Content and SEO teams act on the recommendation by selecting topics and planning content. A wrong recommendation can waste time and resources, target the wrong audience, and reduce content performance.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The dataset contains 30,000 unique content IDs and 32 unique clients. Keyword articles are the largest content type, with 27,207 records. These numbers show that the dataset has enough content and client information to study content opportunities and prioritization.

# %%
import pandas as pd
from pathlib import Path

# Load the dataset
project_root = Path.cwd().parents[1]
csv_path = project_root / "data" / "raw" / "content_refresh_anonymized.csv"

df = pd.read_csv(csv_path)

# Show 3 real numbers
print("Total rows:", len(df))
print("Unique content IDs:", df["content_id"].nunique())
print("Unique clients:", df["client_id"].nunique())
# Out:
# Total rows: 30000
# Unique content IDs: 30000
# Unique clients: 32

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can identify observed patterns and relationships in the dataset and provide directional recommendations to support content planning decisions. I cannot claim that the recommendations will definitely improve performance, prove causation, or predict future results with certainty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [X] Every section above is filled — markdown thinking AND the code that backs it
# - [X] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [X] No client names, URLs, or private queries anywhere
# - [X] My claims use careful words: observed, measured, directional, decision-support
# - [X] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
